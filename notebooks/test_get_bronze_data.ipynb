# %% [markdown]
# <h1 style="
#   font-family: 'Courier New', monospace;
#   font-size: 28px;
#   color: #00f5ff;
#   text-shadow: 0 0 5px #00f5ff, 0 0 15px #00f5ff, 0 0 25px #00f5ff;
# ">
#   Convert google sheet file to DataFrame and Json format
# </h1>
#
# ---

# %%
import pandas as pd

# ID của sheet lấy từ link
# https://docs.google.com/spreadsheets/d/1DcJkKtmH4zrepZ_ofmIrz0yfJLEt2rNqGFRPJN529p0
sheet_id = "1DcJkKtmH4zrepZ_ofmIrz0yfJLEt2rNqGFRPJN529p0"
sheet_name = "Master%20Scholarship" # Replace spaces with %20

# Link export CSV
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %% [markdown]
# <h2 style="
#   font-family: Inter, sans-serif;
#   font-size: 32px;
#   font-weight: 800;
#   background: linear-gradient(90deg, #7c3aed, #06b6d4, #22c55e, #facc15);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
# ">
#   DataFrame
# </h2>

# %%
# Đọc vào DataFrame
df = pd.read_csv(url)
df.columns = df.columns.str.strip().str.replace(" ", "_")

display(df.head())
# Out:
#    STT                                       Tên_học_bổng Loại_học_bổng  \
# 0  1.0                            Chevening  Schoolarship     Chính phủ
# 1  2.0                  Australia Awards Scholarships AAS     Chính phủ
# 2  3.0               Fulbright Vietnamese Student Program     Chính phủ
# 3  4.0                    Manaaki New Zealand Scholarship     Chính phủ
# 4  5.0  Government of Ireland International Education ...     Chính phủ
#
#       Quốc_gia                             Mức_tài_trợ  \
# 0          Anh  Toàn phần, Sinh hoạt phí, Chi phí khác
# 1           Úc  Toàn phần, Sinh hoạt phí, Chi phí khác
# 2       Hoa Kỳ  Toàn phần, Sinh hoạt phí, Chi phí khác
# 3  New Zealand  Toàn phần, Sinh hoạt phí, Chi phí khác
# 4      Ireland                Sinh hoạt phí, Toàn phần
#
#                                     Chi_tiết_tài_trợ Hình_thức_mở  \
# 0  Lệ phí xin thị thực vào Anh\nChi phí làm thủ t...  Thường niên
# 1  học phí\nsinh hoạt phí\nvé máy bay khứ hồi\nbả...  Thường niên
# 2  Học phí\nSinh hoạt phí hàng tháng\nBảo hiểm ốm...  Thường niên
# 3  100% học phí.\nTrợ cấp sinh hoạt (trợ cấp) cho...  Thường niên
# 4  Khoản trợ cấp €10,000 cho một năm học toàn thờ...  Thường niên
#
#   Tháng_mở_đơn_(với_thường_niên)       Ngày_bắt_đầu       Ngày_kết_thúc  ...  \
# 0                              8   8/5/2025 0:00:00  10/7/2025 23:59:59  ...
# 1                              2  1/31/2025 0:00:00  4/30/2025 20:59:59  ...
# 2                             12  12/1/2024 0:00:00   4/1/2025 17:00:00  ...
# 3                              2   2/1/2026 0:00:00   8/31/2026 0:00:00  ...
# 4                             12                NaN   3/6/2025 23:00:00  ...
#
#               Độ_tuổi      Giới_tính  \
# 0       Không yêu cầu  Không yêu cầu
# 1  Từ 18 tuổi trở lên  Không yêu cầu
# 2       Không yêu cầu  Không yêu cầu
# 3  Từ 18 tuổi trở lên  Không yêu cầu
# 4       Không yêu cầu  Không yêu cầu
#
#                                   Hoàn_cảnh_đặc_biệt  \
# 0                                              Không
# 1  Không được kết hôn/đính hôn với công dân/thườn...
# 2                                              Không
# 3                                              Không
# 4                                              Không
#
#                  Kế_hoạch_nghề_nghiệp_sau_tốt_nghiệp  \
# 0  Ứng viên phải cam kết quay trở lại Việt Nam là...
# 1  Yêu cầu phải trở về nước ít nhất 2 năm để đóng...
# 2  Thể hiện sự cống hiến cho Việt Nam và tiềm năn...
# 3  Bắt buộc cam kết quay về nước ít nhất 2 năm để...
# 4  Trình bày rõ ràng định hướng nghề nghiệp và tạ...
#
#                                         Yêu_cầu_Khác  \
# 0  Lãnh đạo, Kết nối, Cam kết trở về, Tác động xã...
# 1                           Cam kết trở về, Tầm nhìn
# 2  Lãnh đạo, Kết nối, Cam kết trở về, Tầm nhìn, H...
# 3  Lãnh đạo, Cam kết trở về, Kết nối, Tác động xã...
# 4  Lãnh đạo, Kỹ năng giao tiếp, Cam kết trở về, H...
#
#                                   Thông_tin_học_bổng  \
# 0  Học bổng Chevening là một chương trình học bổn...
# 1  Học bổng dài hạn, toàn phần do Bộ Ngoại giao v...
# 2  Phái đoàn Ngoại giao Hoa Kỳ tại Việt Nam tìm k...
# 3  Học bổng toàn phần do Chính phủ New Zealand tà...
# 4  Học bổng Giáo dục Quốc tế Chính phủ Ireland (G...
#
#                                                Hồ_sơ  \
# 0  Đơn online nộp tại https://www.chevening.org/v...
# 1  \nĐơn online qua hệ thống OASIS hoặc bản cứng\...
# 2  Đơn dự tuyển trực tuyến nộp tại https://apply....
# 3  Thư giới thiệu (nếu có).\nGiấy xác nhận tình t...
# 4  Đơn online\n2 thư giới thiệu\nonditional/final...
#
#                                             Timeline  \
# 0  5/8 – 7/10/2025: Mở đơn \nTháng 10 - tháng 1: ...
# 1                                                NaN
# 2  Tháng 12/2024: Thông báo nhận hồ sơ trực tuyến...
# 3                                                NaN
# 4  5/3/2025: Kết thúc vòng hồ sơ\n6/2025: Kết quả...
#
#                                                  URL Unnamed:_35
# 0                         https://www.chevening.org/         NaN
# 1  https://www.dfat.gov.au/people-to-people/austr...         NaN
# 2                    https://us.fulbrightonline.org/         NaN
# 3                https://www.nzscholarships.govt.nz/         NaN
# 4  https://hea.ie/2021/12/02/government-of-irelan...         NaN
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 36 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   STT                                         150 non-null    float64
#  1   Tên_học_bổng                                63 non-null     object
#  2   Loại_học_bổng                               42 non-null     object
#  3   Quốc_gia                                    63 non-null     object
#  4   Mức_tài_trợ                                 100 non-null    object
#  5   Chi_tiết_tài_trợ                            75 non-null     object
#  6   Hình_thức_mở                                121 non-null    object
#  7   Tháng_mở_đơn_(với_thường_niên)              63 non-null     object
#  8   Ngày_bắt_đầu                                26 non-null     object
#  9   Ngày_kết_thúc                               31 non-null     object
#  10  Số_lượng_(nếu_có)                           15 non-null     float64
#  11  Có_dành_cho_sinh_viên_Việt_Nam_không        129 non-null    object
#  12  Giới_hạn_đối_tượng                          98 non-null     object
#  13  Danh_sách_giới_hạn_đối_tượng_(nếu_có)       39 non-null     object
#  14  Giới_hạn_ngành_nghề                         100 non-null    object
#  15  Danh_sách_ngành_nghề_(nếu_có)               26 non-null     object
#  16  Bằng_cấp_yêu_cầu                            121 non-null    object
#  17  GPA_tối_thiểu                               44 non-null     object
#  18  Yêu_cầu_điểm_xếp_hạng_top_của_cử_nhân       45 non-null     object
#  19  Yêu_cầu_sự_liên_quan_của_ngành_học_cử_nhân  121 non-null    object
#  20  Yêu_cầu_số_năm_kinh_nghiệm                  43 non-null     object
#  21  Yêu_cầu_số_giờ_làm_việc_tối_thiểu           42 non-null     object
#  22  Yêu_cầu_chứng_chỉ_ngoại_ngữ                 121 non-null    object
#  23  Yêu_cầu_chứng_chỉ_Academic                  121 non-null    object
#  24  Yêu_cầu_giải_thưởng,_thành_tích_học_thuật   100 non-null    object
#  25  Yêu_cầu_publication                         100 non-null    object
#  26  Độ_tuổi                                     42 non-null     object
#  27  Giới_tính                                   100 non-null    object
#  28  Hoàn_cảnh_đặc_biệt                          30 non-null     object
#  29  Kế_hoạch_nghề_nghiệp_sau_tốt_nghiệp         22 non-null     object
#  30  Yêu_cầu_Khác                                28 non-null     object
#  31  Thông_tin_học_bổng                          42 non-null     object
#  32  Hồ_sơ                                       40 non-null     object
#  33  Timeline                                    32 non-null     object
#  34  URL                                         63 non-null     object
#  35  Unnamed:_35                                 0 non-null      float64
# dtypes: float64(3), object(33)
# memory usage: 45.7+ KB

# %% [markdown]
# ### Preprocessing data Structure

# %%
df = df.dropna(how='all', axis=0)  # Drop rows where all elements are NaN
df = df.dropna(how='all', axis=1)  # Drop columns where all elements are NaN
df = df.drop(columns='STT', axis=1)  # Drop 'STT' column if it exists
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Tên_học_bổng                                63 non-null     object
#  1   Loại_học_bổng                               42 non-null     object
#  2   Quốc_gia                                    63 non-null     object
#  3   Mức_tài_trợ                                 100 non-null    object
#  4   Chi_tiết_tài_trợ                            75 non-null     object
#  5   Hình_thức_mở                                121 non-null    object
#  6   Tháng_mở_đơn_(với_thường_niên)              63 non-null     object
#  7   Ngày_bắt_đầu                                26 non-null     object
#  8   Ngày_kết_thúc                               31 non-null     object
#  9   Số_lượng_(nếu_có)                           15 non-null     float64
#  10  Có_dành_cho_sinh_viên_Việt_Nam_không        129 non-null    object
#  11  Giới_hạn_đối_tượng                          98 non-null     object
#  12  Danh_sách_giới_hạn_đối_tượng_(nếu_có)       39 non-null     object
#  13  Giới_hạn_ngành_nghề                         100 non-null    object
#  14  Danh_sách_ngành_nghề_(nếu_có)               26 non-null     object
#  15  Bằng_cấp_yêu_cầu                            121 non-null    object
#  16  GPA_tối_thiểu                               44 non-null     object
#  17  Yêu_cầu_điểm_xếp_hạng_top_của_cử_nhân       45 non-null     object
#  18  Yêu_cầu_sự_liên_quan_của_ngành_học_cử_nhân  121 non-null    object
#  19  Yêu_cầu_số_năm_kinh_nghiệm                  43 non-null     object
#  20  Yêu_cầu_số_giờ_làm_việc_tối_thiểu           42 non-null     object
#  21  Yêu_cầu_chứng_chỉ_ngoại_ngữ                 121 non-null    object
#  22  Yêu_cầu_chứng_chỉ_Academic                  121 non-null    object
#  23  Yêu_cầu_giải_thưởng,_thành_tích_học_thuật   100 non-null    object
#  24  Yêu_cầu_publication                         100 non-null    object
#  25  Độ_tuổi                                     42 non-null     object
#  26  Giới_tính                                   100 non-null    object
#  27  Hoàn_cảnh_đặc_biệt                          30 non-null     object
#  28  Kế_hoạch_nghề_nghiệp_sau_tốt_nghiệp         22 non-null     object
#  29  Yêu_cầu_Khác                                28 non-null     object
#  30  Thông_tin_học_bổng                          42 non-null     object
#  31  Hồ_sơ                                       40 non-null     object
#  32  Timeline                                    32 non-null     object
#  33  URL                                         63 non-null     object
# dtypes: float64(1), object(33)
# memory usage: 43.2+ KB

# %%
# Translate column names from Vietnamese to English
mapping = {
    "Tên_học_bổng": "Scholarship_Name",
    "Loại_học_bổng": "Scholarship_Type",
    "Quốc_gia": "Country",
    "Mức_tài_trợ": "Funding_Level",
    "Chi_tiết_tài_trợ": "Funding_Details",
    "Hình_thức_mở": "Application_Mode",
    "Tháng_mở_đơn_(với_thường_niên)": "Application_Month",
    "Ngày_bắt_đầu": "Start_Date",
    "Ngày_kết_thúc": "End_Date",
    "Số_lượng_(nếu_có)": "Quantity",
    "Có_dành_cho_sinh_viên_Việt_Nam_không": "For_Vietnamese",
    "Giới_hạn_đối_tượng": "Eligibility",
    "Danh_sách_giới_hạn_đối_tượng_(nếu_có)": "Eligible_Applicants",
    "Giới_hạn_ngành_nghề": "Field_Restriction",
    "Danh_sách_ngành_nghề_(nếu_có)": "Eligible_Fields",
    "Bằng_cấp_yêu_cầu": "Required_Degree",
    "GPA_tối_thiểu": "Min_GPA",
    "Yêu_cầu_điểm_xếp_hạng_top_của_cử_nhân": "Bachelor_Ranking_Requirement",
    "Yêu_cầu_sự_liên_quan_của_ngành_học_cử_nhân": "Bachelor_Field_Relevance",
    "Yêu_cầu_số_năm_kinh_nghiệm": "Experience_Years",
    "Yêu_cầu_số_giờ_làm_việc_tối_thiểu": "Min_Working_Hours",
    "Yêu_cầu_chứng_chỉ_ngoại_ngữ": "Language_Certificate",
    "Yêu_cầu_chứng_chỉ_Academic": "Academic_Certificate",
    "Yêu_cầu_giải_thưởng,_thành_tích_học_thuật": "Awards_Requirement",
    "Yêu_cầu_publication": "Publication_Requirement",
    "Độ_tuổi": "Age",
    "Giới_tính": "Gender",
    "Hoàn_cảnh_đặc_biệt": "Special_Circumstances",
    "Kế_hoạch_nghề_nghiệp_sau_tốt_nghiệp": "Career_Plan",
    "Yêu_cầu_Khác": "Other_Requirements",
    "Thông_tin_học_bổng": "Scholarship_Info",
    "Hồ_sơ": "Application_Documents",
    "Timeline": "Timeline",
    "URL": "URL",
    "Checked": "Checked"
}


# normalize column names to Capitalized_Words format
def normalize_col(name):
    parts = name.split("_")
    return "_".join([p.capitalize() for p in parts])

# Convert DataFrame
df = df.rename(columns=mapping)
df.columns = [normalize_col(c) for c in df.columns]

display(df.tail())
# Out:
#     Scholarship_Name Scholarship_Type Country Funding_Level  \
# 157              NaN              NaN     NaN           NaN
# 158              NaN              NaN     NaN           NaN
# 159              NaN              NaN     NaN           NaN
# 160              NaN              NaN     NaN           NaN
# 161              NaN              NaN     NaN           NaN
#
#             Funding_Details Application_Mode Application_Month Start_Date  \
# 157           Quản trị công              NaN               NaN        NaN
# 158               Marketing              NaN               NaN        NaN
# 159            Data Science              NaN               NaN        NaN
# 160  Kỹ thuật điện, điện tử              NaN               NaN        NaN
# 161               Tài chính              NaN               NaN        NaN
#
#     End_Date  Quantity  ... Publication_Requirement  Age Gender  \
# 157      NaN       NaN  ...                     NaN  NaN    NaN
# 158      NaN       NaN  ...                     NaN  NaN    NaN
# 159      NaN       NaN  ...                     NaN  NaN    NaN
# 160      NaN       NaN  ...                     NaN  NaN    NaN
# 161      NaN       NaN  ...                     NaN  NaN    NaN
#
#     Special_Circumstances Career_Plan Other_Requirements Scholarship_Info  \
# 157                   NaN         NaN                NaN              NaN
# 158                   NaN         NaN                NaN              NaN
# 159                   NaN         NaN                NaN              NaN
# 160                   NaN         NaN                NaN              NaN
# 161                   NaN         NaN                NaN              NaN
#
#     Application_Documents Timeline  Url
# 157                   NaN      NaN  NaN
# 158                   NaN      NaN  NaN
# 159                   NaN      NaN  NaN
# 160                   NaN      NaN  NaN
# 161                   NaN      NaN  NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ---
# Trong DataFrame đang có các cột dữ liệu dạng chuỗi (text), nhưng thực tế thì nó có **2 loại tính chất khác nhau**:
#
# 1. **Dạng phân loại (categorical text)** – ví dụ:
#
#    * `Loại học bổng`: "Chính phủ", "Trường", "Quỹ/Tổ chức"...
#    * Đây là số lượng giá trị duy nhất (unique values) ít, lặp đi lặp lại.
#      👉 Nên được xử lý như **Categorical data** (`pandas.Categorical`) hoặc để string nhưng sau này encode (Label Encoding, One-hot Encoding, …).
#    * Lưu `category` sẽ tiết kiệm bộ nhớ và thuận tiện cho phân tích.
#
# 2. **Dạng mô tả tự do (free text / natural text)** – ví dụ:
#
#    * `Miêu tả học bổng`: đoạn văn dài, mỗi bản ghi khác nhau hoàn toàn, không lặp.
#      👉 Đây thì cứ để dạng `string` (hoặc `object` nếu pandas version cũ).
#    * Sau này nếu cần xử lý NLP thì tách token, vectorize (TF-IDF, Word2Vec, BERT embedding…), hoặc tóm tắt nội dung.

# %%
df.columns
# Out:
# Index(['Scholarship_Name', 'Scholarship_Type', 'Country', 'Funding_Level',
#        'Funding_Details', 'Application_Mode', 'Application_Month',
#        'Start_Date', 'End_Date', 'Quantity', 'For_Vietnamese', 'Eligibility',
#        'Eligible_Applicants', 'Field_Restriction', 'Eligible_Fields',
#        'Required_Degree', 'Min_Gpa', 'Bachelor_Ranking_Requirement',
#        'Bachelor_Field_Relevance', 'Experience_Years', 'Min_Working_Hours',
#        'Language_Certificate', 'Academic_Certificate', 'Awards_Requirement',
#        'Publication_Requirement', 'Age', 'Gender', 'Special_Circumstances',
#        'Career_Plan', 'Other_Requirements', 'Scholarship_Info',
#        'Application_Documents', 'Timeline', 'Url'],
#       dtype='object')

# %%
category_cols = ['Scholarship_Type', 
                 'Country', 
                 'Funding_Level', 
                 'Application_Mode', 
                 'Application_Month', 
                 'For_Vietnamese',
                 'Eligibility', 
                 'Eligible_Applicants',
                 'Field_Restriction', 
                 'Required_Degree',
                 'Min_Gpa', 
                 'Bachelor_Field_Relevance',
                 'Language_Certificate',
                 'Academic_Certificate',
                 "Awards_Requirement",
                 "Publication_Requirement",
                 "Age",
                 "Gender",
                 "Other_Requirements",
]

for col in category_cols:
    df[col] = df[col].astype('category')

# %%
real_number_cols = [
    'Experience_Years', 
    'Min_Working_Hours',
]

for col in real_number_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
date_time_cols = [
    'Start_Date', 
    'End_Date',
]

for col in date_time_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
string_cols = [col for col in df.columns if col not in category_cols + real_number_cols + date_time_cols]
for col in string_cols:
    df[col] = df[col].astype('string')

# %%
df.head()
# Out:
#                                     Scholarship_Name Scholarship_Type  \
# 0                            Chevening  Schoolarship        Chính phủ
# 1                  Australia Awards Scholarships AAS        Chính phủ
# 2               Fulbright Vietnamese Student Program        Chính phủ
# 3                    Manaaki New Zealand Scholarship        Chính phủ
# 4  Government of Ireland International Education ...        Chính phủ
#
#        Country                           Funding_Level  \
# 0          Anh  Toàn phần, Sinh hoạt phí, Chi phí khác
# 1           Úc  Toàn phần, Sinh hoạt phí, Chi phí khác
# 2       Hoa Kỳ  Toàn phần, Sinh hoạt phí, Chi phí khác
# 3  New Zealand  Toàn phần, Sinh hoạt phí, Chi phí khác
# 4      Ireland                Sinh hoạt phí, Toàn phần
#
#                                      Funding_Details Application_Mode  \
# 0  Lệ phí xin thị thực vào Anh\nChi phí làm thủ t...      Thường niên
# 1  học phí\nsinh hoạt phí\nvé máy bay khứ hồi\nbả...      Thường niên
# 2  Học phí\nSinh hoạt phí hàng tháng\nBảo hiểm ốm...      Thường niên
# 3  100% học phí.\nTrợ cấp sinh hoạt (trợ cấp) cho...      Thường niên
# 4  Khoản trợ cấp €10,000 cho một năm học toàn thờ...      Thường niên
#
#   Application_Month Start_Date            End_Date Quantity  ...  \
# 0                 8 2025-08-05 2025-10-07 23:59:59     <NA>  ...
# 1                 2 2025-01-31 2025-04-30 20:59:59   1151.0  ...
# 2                12 2024-12-01 2025-04-01 17:00:00     <NA>  ...
# 3                 2 2026-02-01 2026-08-31 00:00:00     <NA>  ...
# 4                12        NaT 2025-03-06 23:00:00     60.0  ...
#
#   Publication_Requirement                 Age         Gender  \
# 0                   Không       Không yêu cầu  Không yêu cầu
# 1                   Không  Từ 18 tuổi trở lên  Không yêu cầu
# 2                   Không       Không yêu cầu  Không yêu cầu
# 3                   Không  Từ 18 tuổi trở lên  Không yêu cầu
# 4                   Không       Không yêu cầu  Không yêu cầu
#
#                                Special_Circumstances  \
# 0                                              Không
# 1  Không được kết hôn/đính hôn với công dân/thườn...
# 2                                              Không
# 3                                              Không
# 4                                              Không
#
#                                          Career_Plan  \
# 0  Ứng viên phải cam kết quay trở lại Việt Nam là...
# 1  Yêu cầu phải trở về nước ít nhất 2 năm để đóng...
# 2  Thể hiện sự cống hiến cho Việt Nam và tiềm năn...
# 3  Bắt buộc cam kết quay về nước ít nhất 2 năm để...
# 4  Trình bày rõ ràng định hướng nghề nghiệp và tạ...
#
#                                   Other_Requirements  \
# 0  Lãnh đạo, Kết nối, Cam kết trở về, Tác động xã...
# 1                           Cam kết trở về, Tầm nhìn
# 2  Lãnh đạo, Kết nối, Cam kết trở về, Tầm nhìn, H...
# 3  Lãnh đạo, Cam kết trở về, Kết nối, Tác động xã...
# 4  Lãnh đạo, Kỹ năng giao tiếp, Cam kết trở về, H...
#
#                                     Scholarship_Info  \
# 0  Học bổng Chevening là một chương trình học bổn...
# 1  Học bổng dài hạn, toàn phần do Bộ Ngoại giao v...
# 2  Phái đoàn Ngoại giao Hoa Kỳ tại Việt Nam tìm k...
# 3  Học bổng toàn phần do Chính phủ New Zealand tà...
# 4  Học bổng Giáo dục Quốc tế Chính phủ Ireland (G...
#
#                                Application_Documents  \
# 0  Đơn online nộp tại https://www.chevening.org/v...
# 1  \nĐơn online qua hệ thống OASIS hoặc bản cứng\...
# 2  Đơn dự tuyển trực tuyến nộp tại https://apply....
# 3  Thư giới thiệu (nếu có).\nGiấy xác nhận tình t...
# 4  Đơn online\n2 thư giới thiệu\nonditional/final...
#
#                                             Timeline  \
# 0  5/8 – 7/10/2025: Mở đơn \nTháng 10 - tháng 1: ...
# 1                                               <NA>
# 2  Tháng 12/2024: Thông báo nhận hồ sơ trực tuyến...
# 3                                               <NA>
# 4  5/3/2025: Kết thúc vòng hồ sơ\n6/2025: Kết quả...
#
#                                                  Url
# 0                         https://www.chevening.org/
# 1  https://www.dfat.gov.au/people-to-people/austr...
# 2                    https://us.fulbrightonline.org/
# 3                https://www.nzscholarships.govt.nz/
# 4  https://hea.ie/2021/12/02/government-of-irelan...
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Scholarship_Name              63 non-null     string
#  1   Scholarship_Type              42 non-null     category
#  2   Country                       63 non-null     category
#  3   Funding_Level                 100 non-null    category
#  4   Funding_Details               75 non-null     string
#  5   Application_Mode              121 non-null    category
#  6   Application_Month             63 non-null     category
#  7   Start_Date                    24 non-null     datetime64[ns]
#  8   End_Date                      30 non-null     datetime64[ns]
#  9   Quantity                      15 non-null     string
#  10  For_Vietnamese                129 non-null    category
#  11  Eligibility                   98 non-null     category
#  12  Eligible_Applicants           39 non-null     category
#  13  Field_Restriction             100 non-null    category
#  14  Eligible_Fields               26 non-null     string
#  15  Required_Degree               121 non-null    category
#  16  Min_Gpa                       44 non-null     category
#  17  Bachelor_Ranking_Requirement  45 non-null     string
#  18  Bachelor_Field_Relevance      121 non-null    category
#  19  Experience_Years              41 non-null     float64
#  20  Min_Working_Hours             41 non-null     float64
#  21  Language_Certificate          121 non-null    category
#  22  Academic_Certificate          121 non-null    category
#  23  Awards_Requirement            100 non-null    category
#  24  Publication_Requirement       100 non-null    category
#  25  Age                           42 non-null     category
#  26  Gender                        100 non-null    category
#  27  Special_Circumstances         30 non-null     string
#  28  Career_Plan                   22 non-null     string
#  29  Other_Requirements            28 non-null     category
#  30  Scholarship_Info              42 non-null     string
#  31  Application_Documents         40 non-null     string
#  32  Timeline                      32 non-null     string
#  33  Url                           63 non-null     string
# dtypes: category(19), datetime64[ns](2), float64(2), string(11)
# memory usage: 30.4 KB

# %%
import os

cur_dir = os.getcwd()
parent_dir = os.path.dirname(cur_dir)
data_dir = os.path.join(parent_dir, 'data')
bronze_data_path = os.path.join(data_dir, '1_bronze')


df.to_csv(
    os.path.join(bronze_data_path, "scholarships.csv"), 
    index=False
)

df.to_parquet(
    os.path.join(bronze_data_path, "scholarships.parquet"), 
    engine="pyarrow", # Or engine = "fastparquet"
    index=False)

# %% [markdown]
# <h1 style="
#   font-family: Inter, sans-serif;
#   font-size: 32px;
#   font-weight: 800;
#   background: linear-gradient(90deg, #7c3aed, #06b6d4, #22c55e, #facc15);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
# ">
#   Json Format
# </h1>

# %%
# xuất json mặc định (mỗi cột là 1 dict)
df.to_json(
    os.path.join(bronze_data_path, "scholarships.json"),
    orient="records",
    force_ascii=False,
    indent=2,
    date_format="iso"    # --> "2025-09-19T10:00:00.000Z"
)

# %%
json_data = pd.read_json(os.path.join(bronze_data_path, "scholarships.json"), orient="records")
json_data
# Out:
#                                       Scholarship_Name Scholarship_Type  \
# 0                              Chevening  Schoolarship        Chính phủ
# 1                    Australia Awards Scholarships AAS        Chính phủ
# 2                 Fulbright Vietnamese Student Program        Chính phủ
# 3                      Manaaki New Zealand Scholarship        Chính phủ
# 4    Government of Ireland International Education ...        Chính phủ
# ..                                                 ...              ...
# 157                                               None             None
# 158                                               None             None
# 159                                               None             None
# 160                                               None             None
# 161                                               None             None
#
#          Country                           Funding_Level  \
# 0            Anh  Toàn phần, Sinh hoạt phí, Chi phí khác
# 1             Úc  Toàn phần, Sinh hoạt phí, Chi phí khác
# 2         Hoa Kỳ  Toàn phần, Sinh hoạt phí, Chi phí khác
# 3    New Zealand  Toàn phần, Sinh hoạt phí, Chi phí khác
# 4        Ireland                Sinh hoạt phí, Toàn phần
# ..           ...                                     ...
# 157         None                                    None
# 158         None                                    None
# 159         None                                    None
# 160         None                                    None
# 161         None                                    None
#
#                                        Funding_Details Application_Mode  \
# 0    Lệ phí xin thị thực vào Anh\nChi phí làm thủ t...      Thường niên
# 1    học phí\nsinh hoạt phí\nvé máy bay khứ hồi\nbả...      Thường niên
# 2    Học phí\nSinh hoạt phí hàng tháng\nBảo hiểm ốm...      Thường niên
# 3    100% học phí.\nTrợ cấp sinh hoạt (trợ cấp) cho...      Thường niên
# 4    Khoản trợ cấp €10,000 cho một năm học toàn thờ...      Thường niên
# ..                                                 ...              ...
# 157                                      Quản trị công             None
# 158                                          Marketing             None
# 159                                       Data Science             None
# 160                             Kỹ thuật điện, điện tử             None
# 161                                          Tài chính             None
#
#     Application_Month               Start_Date                 End_Date  \
# 0                   8  2025-08-05T00:00:00.000  2025-10-07T23:59:59.000
# 1                   2  2025-01-31T00:00:00.000  2025-04-30T20:59:59.000
# 2                  12  2024-12-01T00:00:00.000  2025-04-01T17:00:00.000
# 3                   2  2026-02-01T00:00:00.000  2026-08-31T00:00:00.000
# 4                  12                     None  2025-03-06T23:00:00.000
# ..                ...                      ...                      ...
# 157              None                     None                     None
# 158              None                     None                     None
# 159              None                     None                     None
# 160              None                     None                     None
# 161              None                     None                     None
#
#      Quantity  ...  Publication_Requirement                 Age  \
# 0         NaN  ...                    Không       Không yêu cầu
# 1      1151.0  ...                    Không  Từ 18 tuổi trở lên
# 2         NaN  ...                    Không       Không yêu cầu
# 3         NaN  ...                    Không  Từ 18 tuổi trở lên
# 4        60.0  ...                    Không       Không yêu cầu
# ..        ...  ...                      ...                 ...
# 157       NaN  ...                     None                None
# 158       NaN  ...                     None                None
# 159       NaN  ...                     None                None
# 160       NaN  ...                     None                None
# 161       NaN  ...                     None                None
#
#             Gender                              Special_Circumstances  \
# 0    Không yêu cầu                                              Không
# 1    Không yêu cầu  Không được kết hôn/đính hôn với công dân/thườn...
# 2    Không yêu cầu                                              Không
# 3    Không yêu cầu                                              Không
# 4    Không yêu cầu                                              Không
# ..             ...                                                ...
# 157           None                                               None
# 158           None                                               None
# 159           None                                               None
# 160           None                                               None
# 161           None                                               None
#
#                                            Career_Plan  \
# 0    Ứng viên phải cam kết quay trở lại Việt Nam là...
# 1    Yêu cầu phải trở về nước ít nhất 2 năm để đóng...
# 2    Thể hiện sự cống hiến cho Việt Nam và tiềm năn...
# 3    Bắt buộc cam kết quay về nước ít nhất 2 năm để...
# 4    Trình bày rõ ràng định hướng nghề nghiệp và tạ...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
#                                     Other_Requirements  \
# 0    Lãnh đạo, Kết nối, Cam kết trở về, Tác động xã...
# 1                             Cam kết trở về, Tầm nhìn
# 2    Lãnh đạo, Kết nối, Cam kết trở về, Tầm nhìn, H...
# 3    Lãnh đạo, Cam kết trở về, Kết nối, Tác động xã...
# 4    Lãnh đạo, Kỹ năng giao tiếp, Cam kết trở về, H...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
#                                       Scholarship_Info  \
# 0    Học bổng Chevening là một chương trình học bổn...
# 1    Học bổng dài hạn, toàn phần do Bộ Ngoại giao v...
# 2    Phái đoàn Ngoại giao Hoa Kỳ tại Việt Nam tìm k...
# 3    Học bổng toàn phần do Chính phủ New Zealand tà...
# 4    Học bổng Giáo dục Quốc tế Chính phủ Ireland (G...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
#                                  Application_Documents  \
# 0    Đơn online nộp tại https://www.chevening.org/v...
# 1    \nĐơn online qua hệ thống OASIS hoặc bản cứng\...
# 2    Đơn dự tuyển trực tuyến nộp tại https://apply....
# 3    Thư giới thiệu (nếu có).\nGiấy xác nhận tình t...
# 4    Đơn online\n2 thư giới thiệu\nonditional/final...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
#                                               Timeline  \
# 0    5/8 – 7/10/2025: Mở đơn \nTháng 10 - tháng 1: ...
# 1                                                 None
# 2    Tháng 12/2024: Thông báo nhận hồ sơ trực tuyến...
# 3                                                 None
# 4    5/3/2025: Kết thúc vòng hồ sơ\n6/2025: Kết quả...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
#                                                    Url
# 0                           https://www.chevening.org/
# 1    https://www.dfat.gov.au/people-to-people/austr...
# 2                      https://us.fulbrightonline.org/
# 3                  https://www.nzscholarships.govt.nz/
# 4    https://hea.ie/2021/12/02/government-of-irelan...
# ..                                                 ...
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
#
# [162 rows x 34 columns]
